# %% [markdown]
# # VNNLib Fuzzing with ACTFuzzer
#
# Inference-based whitebox fuzzing on CIFAR-100 VNNLib benchmarks to find counterexamples.

# %%
# Setup and imports
import sys, os
act_root = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
sys.path.insert(0, act_root) if act_root not in sys.path else None

import torch
import matplotlib.pyplot as plt
import numpy as np
import yaml
from pathlib import Path

# Force reload all fuzzing modules to pick up latest changes
import importlib
modules_to_reload = [
    'act.pipeline.fuzzing.mutations',
    'act.pipeline.fuzzing.coverage',
    'act.pipeline.fuzzing.corpus',
    'act.pipeline.fuzzing.checker',
    'act.pipeline.fuzzing.actfuzzer',
    'act.front_end.model_synthesis',
    'act.front_end.vnnlib_loader.create_specs',
    'act.front_end.vnnlib_loader.vnnlib_parser',
    'act.front_end.vnnlib_loader.onnx_converter',
    'act.front_end.vnnlib_loader.data_model_loader',
]
for mod_name in modules_to_reload:
    if mod_name in sys.modules:
        importlib.reload(sys.modules[mod_name])

from act.front_end.vnnlib_loader.create_specs import VNNLibSpecCreator
from act.front_end.model_synthesis import synthesize_models_from_specs
from act.pipeline.fuzzing.actfuzzer import ACTFuzzer, FuzzingConfig

# CIFAR-100 class names (100 fine-grained classes)
CIFAR100_CLASSES = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

print("✓ Setup complete (modules reloaded with batch dimension fixes)")
# Out:
# ✓ Setup complete (modules reloaded with batch dimension fixes)

# %% [markdown]
# ## Load VNNLib Benchmark and Run Fuzzing (1-minute budget)
#
# **Note on VNNLib Property Format:**
# - VNNLib benchmarks encode robustness as: `Y_i >= Y_true` for all i ≠ true
# - This means: "all wrong classes must have logits ≥ true class logit"
# - A **counterexample** (violation) occurs when the model predicts a different class (misclassification)
# - The fuzzer tries to find inputs within ε that cause misclassification

# %%
print("="*80)
print("LOADING CIFAR-100 VNNLIB BENCHMARK")
print("="*80)

# Load VNNLib instances
creator = VNNLibSpecCreator(config_name="vnnlib_default")
spec_results = creator.create_specs_for_data_model_pairs(
    categories=["cifar100_2024"],
    max_instances=20,
    validate_shapes=True
)
print(f"✓ Loaded {len(spec_results)} instances\n")

# Randomly select 3 instances for fuzzing
# import random
# num_seeds = 3
# random_indices = random.sample(range(len(spec_results)), min(num_seeds, len(spec_results)))
# print(f"🎲 Randomly selected {len(random_indices)} instances: {[i+1 for i in random_indices]}\n")

# selected_instances = [spec_results[i] for i in random_indices]
selected_instances = spec_results[:2]
# Synthesize wrapped models for all selected instances
# Note: synthesize_models_from_specs returns (wrapped_models, reports) tuple
print("Synthesizing wrapped models for selected instances...")
wrapped_models, reports = synthesize_models_from_specs(selected_instances)
print(f"✓ Models wrapped for {len(wrapped_models)} instances\n")

# Load fuzzing config from YAML
config_path = Path(act_root) / "act/pipeline/fuzzing/config.yaml"
with open(config_path) as f:
    yaml_data = yaml.safe_load(f)
    yaml_config = yaml_data['fuzzing']

# Override with 1-minute budget per instance + ENABLE TRACING
config = FuzzingConfig(
    max_iterations=yaml_config['max_iterations'],
    timeout_seconds=60.0,  # 1 minute per instance
    device="cuda" if torch.cuda.is_available() else "cpu",
    save_counterexamples=yaml_config['save_counterexamples'],
    output_dir=Path("fuzzing_results_vnnlib"),
    report_interval=yaml_config['report_interval'],
    mutation_weights=yaml_config['mutation_weights'],
    coverage_strategy=yaml_config['coverage_strategy'],
    activation_threshold=yaml_config['activation_threshold'],
    # ============================================================================
    # 🔍 TRACING ENABLED: Capture fuzzing execution traces for analysis
    # ============================================================================
    trace_level=1,           # 1=default (strategies, coverage), 2=full (+ input snapshots)
    trace_sample_rate=10,     # Capture every iteration (1=all, 10=every 10th, etc.)
    trace_storage="json",    # Storage format: "json" or "hdf5"
    trace_output=None        # Auto-generate path in output_dir/traces.json
)

print(f"Fuzzing config: timeout={config.timeout_seconds}s per instance, device={config.device}")
print(f"Mutation weights: {config.mutation_weights}")
print(f"🔍 Tracing: ENABLED (level={config.trace_level}, storage={config.trace_storage})\n")

print("="*80)
print("STARTING FUZZING - ONE MODEL PER INSTANCE")
print("="*80)

# Fuzz each wrapped model independently
all_reports = []
all_fuzzers = []  # Store all fuzzers to access their corpus seeds
instance_info = []
trace_files = []  # Store trace file paths for each instance

for idx, (combo_id, wrapped_model) in enumerate(wrapped_models.items()):
    # Extract labeled input from model's InputLayer
    input_layer = wrapped_model[0]  # First layer is InputLayer
    labeled_input = input_layer.labeled_input  # LabeledInputTensor
    
    # Extract input spec from InputSpecLayer (second layer)
    input_spec_layer = wrapped_model[1]  # Second layer is InputSpecLayer
    input_spec = input_spec_layer.spec  # Access .spec attribute
    epsilon = float((input_spec.ub - input_spec.lb).max())
    
    # Extract output spec from OutputSpecLayer (last layer)
    output_spec_layer = wrapped_model[-1]  # Last layer is OutputSpecLayer
    output_spec = output_spec_layer.spec  # Access .spec attribute
    
    print(f"\n[{idx+1}/{len(wrapped_models)}] Instance: {combo_id}")
    print(f"   True label: {labeled_input.label} ({CIFAR100_CLASSES[labeled_input.label]})")
    print(f"   Epsilon: {epsilon:.6f}")
    
    # Store instance info for visualization
    instance_info.append({
        'index': idx,
        'input_tensor': labeled_input.tensor,
        'true_label': labeled_input.label,
        'epsilon': epsilon,
        'input_spec': input_spec,
        'combo_id': combo_id
    })
    
    # Run fuzzing with this model's stored input as seed
    fuzzer = ACTFuzzer(
        wrapped_model=wrapped_model,
        initial_seeds=[labeled_input],
        config=config
    )
    report = fuzzer.fuzz()
    all_reports.append(report)
    all_fuzzers.append(fuzzer)  # Store fuzzer for this instance
    
    # Store trace file path if tracing is enabled (FIXED: use fuzzer.tracer.output_path)
    if hasattr(fuzzer, 'tracer') and fuzzer.tracer is not None:
        trace_file_path = fuzzer.tracer.output_path
        trace_files.append(trace_file_path)
        print(f"   📊 Trace saved: {trace_file_path}")
    
    print(f"   ✓ Iterations: {report.total_iterations}, "
          f"Time: {report.total_time:.2f}s, "
          f"Counterexamples: {len(report.counterexamples)}")

# Aggregate results
print("\n" + "="*80)
print("FUZZING COMPLETE - ALL INSTANCES")
print("="*80)
total_iterations = sum(r.total_iterations for r in all_reports)
total_time = sum(r.total_time for r in all_reports)
total_counterexamples = sum(len(r.counterexamples) for r in all_reports)
avg_coverage = sum(r.neuron_coverage for r in all_reports) / len(all_reports)

print(f"Total iterations: {total_iterations} ({total_iterations / total_time:.1f} it/s)")
print(f"Total time: {total_time:.2f}s")
print(f"Total counterexamples: {total_counterexamples}")
print(f"Average coverage: {avg_coverage:.2%}")
print("="*80)

# Combine all counterexamples and create a unified report for visualization
report = type('CombinedReport', (), {
    'total_iterations': total_iterations,
    'total_time': total_time,
    'counterexamples': [ce for r in all_reports for ce in r.counterexamples],
    'neuron_coverage': avg_coverage,
    'seeds_explored': sum(r.seeds_explored for r in all_reports)
})()
# Out:
# INFO:act.front_end.vnnlib_loader.create_specs:Creating VNNLIB specs: categories=['cifar100_2024'], max_instances=20
# INFO:act.front_end.vnnlib_loader.create_specs:Processing 20 VNNLIB instances
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_116_sidx_8002_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 85
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_116_sidx_8002_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# ================================================================================
# LOADING CIFAR-100 VNNLIB BENCHMARK
# ================================================================================
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4071_sidx_6244_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 74
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4071_sidx_6244_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_1862_sidx_1111_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 84
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_1862_sidx_1111_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4141_sidx_5393_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 61
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4141_sidx_5393_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_1208_sidx_4993_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 71
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_1208_sidx_4993_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_2753_sidx_3773_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 59
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_2753_sidx_3773_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_3673_sidx_32_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 81
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_3673_sidx_32_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_3717_sidx_7096_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 36
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_3717_sidx_7096_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_3767_sidx_7124_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 43
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_3767_sidx_7124_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_2640_sidx_6925_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_medium.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_medium.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 78
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_2640_sidx_6925_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_2575_sidx_1066_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 55
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_2575_sidx_1066_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_5130_sidx_3546_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 73
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_5130_sidx_3546_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_5346_sidx_2357_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 1
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_5346_sidx_2357_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_9686_sidx_6346_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 10
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_9686_sidx_6346_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_9099_sidx_8444_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 33
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_9099_sidx_8444_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_4251_sidx_1755_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 53
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_4251_sidx_1755_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_8502_sidx_2893_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 25
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_8502_sidx_2893_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_1372_sidx_9800_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 40
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_1372_sidx_9800_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_3498_sidx_1404_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 34
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_3498_sidx_1404_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Loading instance: cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_1827_sidx_2176_eps_0.0039
# INFO:act.front_end.vnnlib_loader.data_model_loader:Loading VNNLIB instance: cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:[1/3] Converting ONNX model to PyTorch...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Loading ONNX model from /data1/guanqin/ACT/data/vnnlib/cifar100_2024/onnx/CIFAR100_resnet_large.onnx
# WARNING:act.front_end.vnnlib_loader.onnx_converter:onnxsim not available, skipping simplification
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converting ONNX to PyTorch
# INFO:act.front_end.vnnlib_loader.onnx_converter:Converted model to device=cpu, dtype=torch.float64
# INFO:act.front_end.vnnlib_loader.onnx_converter:Successfully converted ONNX model: CIFAR100_resnet_large.onnx
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Model converted successfully
# INFO:act.front_end.vnnlib_loader.data_model_loader:[2/3] Extracting input shape...
# INFO:act.front_end.vnnlib_loader.onnx_converter:Normalized dynamic batch to 1: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Input shape: (1, 3, 32, 32)
# INFO:act.front_end.vnnlib_loader.data_model_loader:[3/3] Parsing VNNLIB specification...
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Parsed VNNLIB: 3072 inputs, 100 outputs, type=unknown
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Parsed VNNLIB: 3072 inputs, 100 outputs
# INFO:act.front_end.vnnlib_loader.data_model_loader:  ✓ Ground truth label: 71
# INFO:act.front_end.vnnlib_loader.data_model_loader:Successfully loaded VNNLIB instance from 'cifar100_2024'
# INFO:act.front_end.vnnlib_loader.create_specs:Generating specs for cifar100_2024/CIFAR100_resnet_large_CIFAR100_resnet_large_prop_idx_1827_sidx_2176_eps_0.0039
# INFO:act.front_end.vnnlib_loader.vnnlib_parser:Created specs from VNNLIB: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Parsed VNNLIB specs: BOX, TOP1_ROBUST
# INFO:act.front_end.vnnlib_loader.create_specs:Successfully created specs for 20 instances
# ✓ Loaded 20 instances
#
# Synthesizing wrapped models for selected instances...
#
# 🧬 Synthesizing models from 2 spec result(s)...
# ✓ cifar100_2024 + CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_116_sidx_8002_eps_0.0039: Created 1 wrapped model(s)
# ✓ cifar100_2024 + CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4071_sidx_6244_eps_0.0039: Created 1 wrapped model(s)
#
# 🎉 Synthesized 2 wrapped models from specs!
# ✓ Models wrapped for 2 instances
#
# Fuzzing config: timeout=60.0s per instance, device=cpu
# Mutation weights: {'gradient': 0, 'pgd': 0.4, 'activation': 0.3, 'boundary': 0.2, 'random': 0.1}
# 🔍 Tracing: ENABLED (level=1, storage=json)
#
# ================================================================================
# STARTING FUZZING - ONE MODEL PER INSTANCE
# ================================================================================
#
# [1/2] Instance: m:CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_116_sidx_8002_eps_0.0039|x:cifar100_2024|s:0|is:BOX|os:TOP1_ROBUST_m0.0
#    True label: 85 (tank)
#    Epsilon: 0.030590
# [MutationEngine] Adaptive Scalar Perturbation Size:
#   - perturb_scale: 0.1 (fraction of range per perturbation)
#   - mean_range: 0.029446
#   - computed perturb_size: 0.002945
#   - steps_to_traverse: ~10.0 steps
#   - interpretation: Each mutation perturbation covers 10.0% of the range
# 📊 Tracing enabled: Level 1, sampling every 10 iteration(s)
#    Output: fuzzing_results_vnnlib/traces.json
# ================================================================================
# ACT: Abstract Constraint Transformer
# Inference-based whitebox fuzzing for neural network verification
# ================================================================================
#
# 🚀 Starting ACTFuzzer with 1 seeds
#    Device: cpu
#    Max iterations: 10000
#    Timeout: 60.0s
#
# 🚨 Counterexample #1: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #2: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #3: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #4: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #5: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #6: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #7: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #8: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #9: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #10: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #11: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #12: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #13: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #14: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #15: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #16: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #17: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #18: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #19: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #20: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #21: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #22: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #23: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #24: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #25: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #26: TOP1_ROBUST: expected 85, got 89 (conf=0.350)
# 🚨 Counterexample #27: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #28: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #29: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #30: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #31: TOP1_ROBUST: expected 85, got 89 (conf=0.310)
# 🚨 Counterexample #32: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #33: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #34: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #35: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #36: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #37: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #38: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #39: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #40: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #41: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #42: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #43: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #44: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #45: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #46: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #47: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #48: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #49: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #50: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #51: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #52: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #53: TOP1_ROBUST: expected 85, got 89 (conf=0.308)
# 🚨 Counterexample #54: TOP1_ROBUST: expected 85, got 89 (conf=0.349)
# 🚨 Counterexample #55: TOP1_ROBUST: expected 85, got 89 (conf=0.350)
# 🚨 Counterexample #56: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #57: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #58: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #59: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #60: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #61: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #62: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #63: TOP1_ROBUST: expected 85, got 89 (conf=0.420)
# 🚨 Counterexample #64: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #65: TOP1_ROBUST: expected 85, got 89 (conf=0.396)
# 🚨 Counterexample #66: TOP1_ROBUST: expected 85, got 89 (conf=0.392)
# 🚨 Counterexample #67: TOP1_ROBUST: expected 85, got 89 (conf=0.390)
# ...
# 🚨 Counterexample #880: TOP1_ROBUST: expected 85, got 89 (conf=0.420)
# 🚨 Counterexample #881: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #882: TOP1_ROBUST: expected 85, got 89 (conf=0.307)
# 🚨 Counterexample #883: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #884: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #885: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #886: TOP1_ROBUST: expected 85, got 89 (conf=0.416)
# 🚨 Counterexample #887: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #888: TOP1_ROBUST: expected 85, got 89 (conf=0.433)
# 🚨 Counterexample #889: TOP1_ROBUST: expected 85, got 89 (conf=0.423)
# 🚨 Counterexample #890: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #891: TOP1_ROBUST: expected 85, got 89 (conf=0.388)
# 🚨 Counterexample #892: TOP1_ROBUST: expected 85, got 89 (conf=0.419)
# 🚨 Counterexample #893: TOP1_ROBUST: expected 85, got 89 (conf=0.440)
# 🚨 Counterexample #894: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #895: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #896: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #897: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 📊 Iteration    900 | Coverage: 55.01% | Seeds:  899 | Violations: 897 | Speed:  17.5 it/s
# 🚨 Counterexample #898: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #899: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #900: TOP1_ROBUST: expected 85, got 89 (conf=0.390)
# 🚨 Counterexample #901: TOP1_ROBUST: expected 85, got 89 (conf=0.392)
# 🚨 Counterexample #902: TOP1_ROBUST: expected 85, got 89 (conf=0.434)
# 🚨 Counterexample #903: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #904: TOP1_ROBUST: expected 85, got 89 (conf=0.407)
# 🚨 Counterexample #905: TOP1_ROBUST: expected 85, got 89 (conf=0.417)
# 🚨 Counterexample #906: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #907: TOP1_ROBUST: expected 85, got 89 (conf=0.422)
# 🚨 Counterexample #908: TOP1_ROBUST: expected 85, got 89 (conf=0.438)
# 🚨 Counterexample #909: TOP1_ROBUST: expected 85, got 89 (conf=0.419)
# 🚨 Counterexample #910: TOP1_ROBUST: expected 85, got 89 (conf=0.416)
# 🚨 Counterexample #911: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #912: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #913: TOP1_ROBUST: expected 85, got 89 (conf=0.418)
# 🚨 Counterexample #914: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #915: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #916: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #917: TOP1_ROBUST: expected 85, got 89 (conf=0.440)
# 🚨 Counterexample #918: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #919: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #920: TOP1_ROBUST: expected 85, got 89 (conf=0.420)
# 🚨 Counterexample #921: TOP1_ROBUST: expected 85, got 89 (conf=0.396)
# 🚨 Counterexample #922: TOP1_ROBUST: expected 85, got 89 (conf=0.435)
# 🚨 Counterexample #923: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #924: TOP1_ROBUST: expected 85, got 89 (conf=0.438)
# 🚨 Counterexample #925: TOP1_ROBUST: expected 85, got 89 (conf=0.388)
# 🚨 Counterexample #926: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #927: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #928: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #929: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #930: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #931: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #932: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #933: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #934: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #935: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #936: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #937: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #938: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #939: TOP1_ROBUST: expected 85, got 89 (conf=0.424)
# 🚨 Counterexample #940: TOP1_ROBUST: expected 85, got 89 (conf=0.435)
# 🚨 Counterexample #941: TOP1_ROBUST: expected 85, got 89 (conf=0.392)
# 🚨 Counterexample #942: TOP1_ROBUST: expected 85, got 89 (conf=0.391)
# 🚨 Counterexample #943: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #944: TOP1_ROBUST: expected 85, got 89 (conf=0.423)
# 🚨 Counterexample #945: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #946: TOP1_ROBUST: expected 85, got 89 (conf=0.442)
# 🚨 Counterexample #947: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #948: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #949: TOP1_ROBUST: expected 85, got 89 (conf=0.428)
# 🚨 Counterexample #950: TOP1_ROBUST: expected 85, got 89 (conf=0.350)
# 🚨 Counterexample #951: TOP1_ROBUST: expected 85, got 89 (conf=0.429)
# 🚨 Counterexample #952: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #953: TOP1_ROBUST: expected 85, got 89 (conf=0.310)
# 🚨 Counterexample #954: TOP1_ROBUST: expected 85, got 89 (conf=0.429)
# 🚨 Counterexample #955: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #956: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #957: TOP1_ROBUST: expected 85, got 89 (conf=0.390)
# 🚨 Counterexample #958: TOP1_ROBUST: expected 85, got 89 (conf=0.441)
# 🚨 Counterexample #959: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #960: TOP1_ROBUST: expected 85, got 89 (conf=0.420)
# 🚨 Counterexample #961: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #962: TOP1_ROBUST: expected 85, got 89 (conf=0.423)
# 🚨 Counterexample #963: TOP1_ROBUST: expected 85, got 89 (conf=0.430)
# 🚨 Counterexample #964: TOP1_ROBUST: expected 85, got 89 (conf=0.441)
# 🚨 Counterexample #965: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #966: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #967: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #968: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #969: TOP1_ROBUST: expected 85, got 89 (conf=0.352)
# 🚨 Counterexample #970: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #971: TOP1_ROBUST: expected 85, got 89 (conf=0.422)
# 🚨 Counterexample #972: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #973: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #974: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #975: TOP1_ROBUST: expected 85, got 89 (conf=0.440)
# 🚨 Counterexample #976: TOP1_ROBUST: expected 85, got 89 (conf=0.417)
# 🚨 Counterexample #977: TOP1_ROBUST: expected 85, got 89 (conf=0.354)
# 🚨 Counterexample #978: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #979: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #980: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #981: TOP1_ROBUST: expected 85, got 89 (conf=0.419)
# 🚨 Counterexample #982: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #983: TOP1_ROBUST: expected 85, got 89 (conf=0.427)
# 🚨 Counterexample #984: TOP1_ROBUST: expected 85, got 89 (conf=0.419)
# 🚨 Counterexample #985: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #986: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #987: TOP1_ROBUST: expected 85, got 89 (conf=0.421)
# 🚨 Counterexample #988: TOP1_ROBUST: expected 85, got 89 (conf=0.390)
# 🚨 Counterexample #989: TOP1_ROBUST: expected 85, got 89 (conf=0.391)
# 🚨 Counterexample #990: TOP1_ROBUST: expected 85, got 89 (conf=0.428)
# 🚨 Counterexample #991: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #992: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #993: TOP1_ROBUST: expected 85, got 89 (conf=0.441)
# 🚨 Counterexample #994: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #995: TOP1_ROBUST: expected 85, got 89 (conf=0.440)
# 🚨 Counterexample #996: TOP1_ROBUST: expected 85, got 89 (conf=0.309)
# 🚨 Counterexample #997: TOP1_ROBUST: expected 85, got 89 (conf=0.441)
# 📊 Iteration   1000 | Coverage: 55.01% | Seeds:  999 | Violations: 997 | Speed:  17.4 it/s
# 🚨 Counterexample #998: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #999: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #1000: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #1001: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #1002: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #1003: TOP1_ROBUST: expected 85, got 89 (conf=0.432)
# 🚨 Counterexample #1004: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #1005: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #1006: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #1007: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #1008: TOP1_ROBUST: expected 85, got 89 (conf=0.411)
# 🚨 Counterexample #1009: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #1010: TOP1_ROBUST: expected 85, got 89 (conf=0.420)
# 🚨 Counterexample #1011: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #1012: TOP1_ROBUST: expected 85, got 89 (conf=0.435)
# 🚨 Counterexample #1013: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #1014: TOP1_ROBUST: expected 85, got 89 (conf=0.431)
# 🚨 Counterexample #1015: TOP1_ROBUST: expected 85, got 89 (conf=0.351)
# 🚨 Counterexample #1016: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #1017: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #1018: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #1019: TOP1_ROBUST: expected 85, got 89 (conf=0.394)
# 🚨 Counterexample #1020: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #1021: TOP1_ROBUST: expected 85, got 89 (conf=0.416)
# 🚨 Counterexample #1022: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #1023: TOP1_ROBUST: expected 85, got 89 (conf=0.391)
# 🚨 Counterexample #1024: TOP1_ROBUST: expected 85, got 89 (conf=0.392)
# 🚨 Counterexample #1025: TOP1_ROBUST: expected 85, got 89 (conf=0.414)
# 🚨 Counterexample #1026: TOP1_ROBUST: expected 85, got 89 (conf=0.439)
# 🚨 Counterexample #1027: TOP1_ROBUST: expected 85, got 89 (conf=0.423)
# 🚨 Counterexample #1028: TOP1_ROBUST: expected 85, got 89 (conf=0.421)
# 🚨 Counterexample #1029: TOP1_ROBUST: expected 85, got 89 (conf=0.392)
# 🚨 Counterexample #1030: TOP1_ROBUST: expected 85, got 89 (conf=0.353)
# 🚨 Counterexample #1031: TOP1_ROBUST: expected 85, got 89 (conf=0.424)
# 🚨 Counterexample #1032: TOP1_ROBUST: expected 85, got 89 (conf=0.425)
# 🚨 Counterexample #1033: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #1034: TOP1_ROBUST: expected 85, got 89 (conf=0.310)
# 🚨 Counterexample #1035: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #1036: TOP1_ROBUST: expected 85, got 89 (conf=0.417)
# 🚨 Counterexample #1037: TOP1_ROBUST: expected 85, got 89 (conf=0.310)
# 🚨 Counterexample #1038: TOP1_ROBUST: expected 85, got 89 (conf=0.429)
# 🚨 Counterexample #1039: TOP1_ROBUST: expected 85, got 89 (conf=0.427)
# 🚨 Counterexample #1040: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #1041: TOP1_ROBUST: expected 85, got 89 (conf=0.392)
# 🚨 Counterexample #1042: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #1043: TOP1_ROBUST: expected 85, got 89 (conf=0.436)
# 🚨 Counterexample #1044: TOP1_ROBUST: expected 85, got 89 (conf=0.393)
# 🚨 Counterexample #1045: TOP1_ROBUST: expected 85, got 89 (conf=0.420)
# 🚨 Counterexample #1046: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# 🚨 Counterexample #1047: TOP1_ROBUST: expected 85, got 89 (conf=0.426)
# 🚨 Counterexample #1048: TOP1_ROBUST: expected 85, got 89 (conf=0.395)
# 🚨 Counterexample #1049: TOP1_ROBUST: expected 85, got 89 (conf=0.437)
# ⏱️  Timeout reached after 1053 iterations
#
# ================================================================================
# 🎉 ACTFuzzer completed in 60.1s
#    Iterations: 1053
#    Counterexamples: 1049
#    Coverage: 55.01%
#    Seeds explored: 1051
#    Never-activated neurons: 0
# ================================================================================
#
# ✅ Report saved to fuzzing_results_vnnlib
#
# ================================================================================
# 📊 Tracing Statistics
# ================================================================================
# Level: 1
# Traces captured: 106
# Sample rate: 1/10
# Output: fuzzing_results_vnnlib/traces.json
# ================================================================================
#
#    📊 Trace saved: fuzzing_results_vnnlib/traces.json
#    ✓ Iterations: 1053, Time: 60.05s, Counterexamples: 1049
#
# [2/2] Instance: m:CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4071_sidx_6244_eps_0.0039|x:cifar100_2024|s:0|is:BOX|os:TOP1_ROBUST_m0.0
#    True label: 74 (shrew)
#    Epsilon: 0.030590
# [MutationEngine] Adaptive Scalar Perturbation Size:
#   - perturb_scale: 0.1 (fraction of range per perturbation)
#   - mean_range: 0.029446
#   - computed perturb_size: 0.002945
#   - steps_to_traverse: ~10.0 steps
#   - interpretation: Each mutation perturbation covers 10.0% of the range
# 📊 Tracing enabled: Level 1, sampling every 10 iteration(s)
#    Output: fuzzing_results_vnnlib/traces.json
# ================================================================================
# ACT: Abstract Constraint Transformer
# Inference-based whitebox fuzzing for neural network verification
# ================================================================================
#
# 🚀 Starting ACTFuzzer with 1 seeds
#    Device: cpu
#    Max iterations: 10000
#    Timeout: 60.0s
#
# 📊 Iteration    100 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  17.5 it/s
# 📊 Iteration    200 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  17.3 it/s
# 📊 Iteration    300 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  18.1 it/s
# 📊 Iteration    400 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  18.8 it/s
# 📊 Iteration    500 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  18.9 it/s
# 📊 Iteration    600 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  18.6 it/s
# 📊 Iteration    700 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  19.0 it/s
# 📊 Iteration    800 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  18.8 it/s
# 📊 Iteration    900 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  19.0 it/s
# 📊 Iteration   1000 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  18.8 it/s
# 📊 Iteration   1100 | Coverage: 55.22% | Seeds:    2 | Violations:   0 | Speed:  19.1 it/s
# ⏱️  Timeout reached after 1157 iterations
#
# ================================================================================
# 🎉 ACTFuzzer completed in 60.1s
#    Iterations: 1157
#    Counterexamples: 0
#    Coverage: 55.22%
#    Seeds explored: 2
#    Never-activated neurons: 0
# ================================================================================
#
#
# ================================================================================
# 📊 Tracing Statistics
# ================================================================================
# Level: 1
# Traces captured: 116
# Sample rate: 1/10
# Output: fuzzing_results_vnnlib/traces.json
# ================================================================================
#
#    📊 Trace saved: fuzzing_results_vnnlib/traces.json
#    ✓ Iterations: 1157, Time: 60.07s, Counterexamples: 0
#
# ================================================================================
# FUZZING COMPLETE - ALL INSTANCES
# ================================================================================
# Total iterations: 2210 (18.4 it/s)
# Total time: 120.12s
# Total counterexamples: 1049
# Average coverage: 55.11%
# ================================================================================

# %% [markdown]
# ## Visualize Results

# %%
# Print fuzzing summary first
print(f"\n{'='*80}")
print(f"FUZZING SUMMARY")
print(f"{'='*80}")
print(f"  Iterations: {report.total_iterations} ({report.total_iterations / report.total_time:.1f} it/s)")
print(f"  Time: {report.total_time:.2f}s")
print(f"  Seeds explored: {report.seeds_explored}")
print(f"  Neuron coverage: {report.neuron_coverage:.2%}")
print(f"  Counterexamples: {len(report.counterexamples)}")
print(f"{'='*80}\n")

# Analyze each instance
print(f"{'='*80}")
print(f"ORIGINAL INPUTS ANALYSIS")
print(f"{'='*80}")

# Get list of wrapped models for inference
wrapped_models_list = list(wrapped_models.values())

for info in instance_info:
    input_tensor = info['input_tensor']
    true_label = info['true_label']
    instance_idx = info['index']
    wrapped_model = wrapped_models_list[instance_idx]
    
    # Ensure input has batch dimension
    if input_tensor.dim() == 3:
        input_batch = input_tensor.unsqueeze(0)
    else:
        input_batch = input_tensor
    
    with torch.no_grad():
        orig_output = wrapped_model(input_batch)
        if isinstance(orig_output, dict):
            orig_output = orig_output['output']
        orig_pred = orig_output.argmax(dim=1).item()
        orig_probs = torch.softmax(orig_output[0], dim=0)
        orig_conf = orig_probs[orig_pred].item()
    
    status = "✓ Correct" if orig_pred == true_label else "✗ MISCLASSIFIED"
    print(f"Instance {info['index']+1}: True={CIFAR100_CLASSES[true_label]}, "
          f"Pred={CIFAR100_CLASSES[orig_pred]} ({orig_conf:.3f}) {status}")

print(f"{'='*80}\n")

# Print specification summary
print(f"{'='*80}")
print(f"SPECIFICATION SUMMARY")
print(f"{'='*80}")

for info in instance_info:
    input_spec = info['input_spec']
    epsilon = info['epsilon']
    true_label = info['true_label']
    
    print(f"\nInstance {info['index']+1} - {CIFAR100_CLASSES[true_label]}:")
    print(f"  InputSpec:")
    print(f"    Kind: {input_spec.kind}")
    print(f"    Shape: {input_spec.lb.shape}")
    print(f"    Epsilon (L∞): {epsilon:.6f}")
    print(f"    Range: [{input_spec.lb.min():.4f}, {input_spec.ub.max():.4f}]")
    print(f"  VNNLib Property:")
    print(f"    Robustness check: Y_i >= Y_{true_label} for all i ≠ {true_label}")
    print(f"    Meaning: Model should predict '{CIFAR100_CLASSES[true_label]}' for all inputs within ε={epsilon:.6f}")

print(f"\n{'='*80}\n")

# Create comprehensive visualization
if len(report.counterexamples) > 0:
    print(f"{'='*80}")
    print(f"🎯 FOUND {len(report.counterexamples)} COUNTEREXAMPLE(S)!")
    print(f"{'='*80}\n")
    
    # Show counterexample details
    print(f"COUNTEREXAMPLE DETAILS:\n")
    for idx, ce in enumerate(report.counterexamples[:10]):
        print(f"{idx+1}. {ce.kind}: True={CIFAR100_CLASSES[ce.expected]}, "
              f"Predicted={CIFAR100_CLASSES[ce.actual]}, Conf={ce.confidence:.3f}")
    
    # Visualize counterexamples grouped by original instance
    print(f"\n{'='*80}")
    print(f"COUNTEREXAMPLE VISUALIZATION")
    print(f"{'='*80}\n")
    
    num_show = min(10, len(report.counterexamples))
    fig, axes = plt.subplots(num_show, 3, figsize=(12, 4*num_show))
    if num_show == 1:
        axes = axes.reshape(1, -1)
    
    fig.suptitle(f'Counterexamples Found: Original → Perturbation → Perturbed', 
                 fontsize=14, fontweight='bold')
    
    for idx in range(num_show):
        ce = report.counterexamples[idx]
        
        # Find which instance this counterexample is closest to
        perturbed = ce.input.squeeze()
        if perturbed.dim() == 1:
            perturbed = perturbed.reshape(3, 32, 32)
        
        # Find closest original
        min_dist = float('inf')
        closest_idx = 0
        for i, info in enumerate(instance_info):
            orig_tensor = info['input_tensor']
            if orig_tensor.dim() == 4:
                orig_tensor = orig_tensor.squeeze(0)
            dist = (perturbed - orig_tensor.reshape(3, 32, 32)).abs().max()
            if dist < min_dist:
                min_dist = dist
                closest_idx = i
        
        orig_info = instance_info[closest_idx]
        orig_tensor = orig_info['input_tensor']
        if orig_tensor.dim() == 4:
            orig_tensor = orig_tensor.squeeze(0)
        orig_tensor = orig_tensor.reshape(3, 32, 32)
        
        # Original image
        orig_img = orig_tensor.permute(1, 2, 0)
        orig_img_np = np.clip(orig_img.cpu().numpy(), 0, 1)
        
        # Perturbed image
        perturbed_img = perturbed.permute(1, 2, 0)
        perturbed_img_np = np.clip(perturbed_img.cpu().numpy(), 0, 1)
        
        # Perturbation (difference)
        diff = perturbed - orig_tensor
        diff_img = diff.permute(1, 2, 0)
        diff_img_np = diff_img.cpu().numpy()
        # Normalize diff for visualization
        diff_vis = (diff_img_np - diff_img_np.min()) / (diff_img_np.max() - diff_img_np.min() + 1e-8)
        
        # Plot original
        axes[idx, 0].imshow(orig_img_np, interpolation='nearest')
        axes[idx, 0].set_title(f'Original (Inst {closest_idx+1})\n{CIFAR100_CLASSES[ce.expected]}', 
                                fontsize=9, color='green', fontweight='bold')
        axes[idx, 0].axis('off')
        
        # Plot perturbation
        axes[idx, 1].imshow(diff_vis, interpolation='nearest')
        l_inf = diff.abs().max().item()
        axes[idx, 1].set_title(f'Perturbation\nL∞={l_inf:.4f}', fontsize=9)
        axes[idx, 1].axis('off')
        
        # Plot perturbed
        axes[idx, 2].imshow(perturbed_img_np, interpolation='nearest')
        axes[idx, 2].set_title(f'Perturbed\n{CIFAR100_CLASSES[ce.actual]}\nConf={ce.confidence:.2f}', 
                                fontsize=9, color='red', fontweight='bold')
        axes[idx, 2].axis('off')
    
    plt.tight_layout()
    plt.show()
    
    print(f"\n✅ Successfully found adversarial examples!")

else:
    print(f"{'='*80}")
    print(f"⚠️  NO COUNTEREXAMPLES FOUND")
    print(f"{'='*80}\n")
    
    print(f"Fuzzing Summary:")
    print(f"  - Iterations: {report.total_iterations}")
    print(f"  - Seeds explored: {report.seeds_explored}")
    print(f"  - Neuron coverage: {report.neuron_coverage:.2%}")
    print(f"  - Time: {report.total_time:.1f}s\n")
    
    # Create visualization: one row per instance with larger images
    print("Creating visualization for all instances...\n")
    
    num_instances = len(instance_info)
    
    # One row per instance, showing: Original | LB | UB | 3 Attempts
    # Total 6 columns per row
    fig, axes = plt.subplots(num_instances, 6, figsize=(18, 6 * num_instances))
    if num_instances == 1:
        axes = axes.reshape(1, -1)
    
    for inst_idx, info in enumerate(instance_info):
        input_tensor = info['input_tensor']
        true_label = info['true_label']
        input_spec = info['input_spec']
        epsilon = info['epsilon']
        wrapped_model = wrapped_models_list[inst_idx]
        
        # Get corpus seeds for THIS instance's fuzzer
        instance_fuzzer = all_fuzzers[inst_idx]
        instance_corpus_seeds = list(instance_fuzzer.seed_corpus.seeds)
        
        # Ensure input_tensor is 3D (C, H, W) for visualization
        if input_tensor.dim() == 4:
            input_tensor = input_tensor.squeeze(0)
        
        # Get prediction on original (needs batch dimension)
        input_batch = input_tensor.unsqueeze(0)
        with torch.no_grad():
            orig_output = wrapped_model(input_batch)
            if isinstance(orig_output, dict):
                orig_output = orig_output['output']
            orig_pred = orig_output.argmax(dim=1).item()
            orig_probs = torch.softmax(orig_output[0], dim=0)
            orig_conf = orig_probs[orig_pred].item()
        
        # Column 0: Original
        orig_img = input_tensor.reshape(3, 32, 32).permute(1, 2, 0)
        orig_img_np = np.clip(orig_img.cpu().numpy(), 0, 1)
        axes[inst_idx, 0].imshow(orig_img_np, interpolation='nearest')
        axes[inst_idx, 0].set_title(f'Instance {inst_idx+1}\nORIGINAL\n{CIFAR100_CLASSES[true_label]}\n'
                                     f'Pred: {CIFAR100_CLASSES[orig_pred]}\n({orig_conf:.3f})',
                                     fontsize=11, color='blue', fontweight='bold')
        axes[inst_idx, 0].axis('off')
        
        # Column 1: Lower Bound
        lb_tensor = input_spec.lb
        if lb_tensor.dim() == 4:
            lb_tensor = lb_tensor.squeeze(0)
        lb_tensor = lb_tensor.reshape(3, 32, 32)
        lb_img = lb_tensor.permute(1, 2, 0)
        lb_img_np = np.clip(lb_img.cpu().numpy(), 0, 1)
        axes[inst_idx, 1].imshow(lb_img_np, interpolation='nearest')
        
        with torch.no_grad():
            lb_output = wrapped_model(lb_tensor.unsqueeze(0))
            if isinstance(lb_output, dict):
                lb_output = lb_output['output']
            lb_pred = lb_output.argmax(dim=1).item()
            lb_probs = torch.softmax(lb_output[0], dim=0)
            lb_conf = lb_probs[lb_pred].item()
        
        axes[inst_idx, 1].set_title(f'LOWER BOUND\n(Original - ε)\n{CIFAR100_CLASSES[lb_pred]}\n({lb_conf:.2f})',
                                     fontsize=10, color='red' if lb_pred != true_label else 'green')
        axes[inst_idx, 1].axis('off')
        
        # Column 2: Upper Bound
        ub_tensor = input_spec.ub
        if ub_tensor.dim() == 4:
            ub_tensor = ub_tensor.squeeze(0)
        ub_tensor = ub_tensor.reshape(3, 32, 32)
        ub_img = ub_tensor.permute(1, 2, 0)
        ub_img_np = np.clip(ub_img.cpu().numpy(), 0, 1)
        axes[inst_idx, 2].imshow(ub_img_np, interpolation='nearest')
        
        with torch.no_grad():
            ub_output = wrapped_model(ub_tensor.unsqueeze(0))
            if isinstance(ub_output, dict):
                ub_output = ub_output['output']
            ub_pred = ub_output.argmax(dim=1).item()
            ub_probs = torch.softmax(ub_output[0], dim=0)
            ub_conf = ub_probs[ub_pred].item()
        
        axes[inst_idx, 2].set_title(f'UPPER BOUND\n(Original + ε)\n{CIFAR100_CLASSES[ub_pred]}\n({ub_conf:.2f})',
                                     fontsize=10, color='red' if ub_pred != true_label else 'green')
        axes[inst_idx, 2].axis('off')
        
        # Columns 3-5: 3 perturbation attempts from THIS instance's corpus
        instance_seeds = []
        for seed in instance_corpus_seeds:
            seed_tensor = seed.tensor
            if seed_tensor.dim() == 4:
                seed_tensor = seed_tensor.squeeze(0)
            seed_tensor = seed_tensor.reshape(3, 32, 32)
            seed_tensor = seed_tensor.to(input_tensor.device)
            dist = (seed_tensor - input_tensor.reshape(3, 32, 32)).abs().max().item()
            if dist <= epsilon * 2:  # Within reasonable range
                instance_seeds.append((seed, dist))
        
        # Sort by distance and take closest 3 (excluding the original which has dist ~0)
        instance_seeds.sort(key=lambda x: x[1])
        # Skip seeds that are too close to the original (likely the original itself)
        instance_seeds = [s for s in instance_seeds if s[1] > 1e-6][:3]
        
        for seed_idx, (seed, dist) in enumerate(instance_seeds):
            col = 3 + seed_idx
            
            seed_tensor = seed.tensor
            if seed_tensor.dim() == 4:
                seed_tensor = seed_tensor.squeeze(0)
            seed_tensor = seed_tensor.reshape(3, 32, 32)
            img = seed_tensor.permute(1, 2, 0)
            img_np = np.clip(img.cpu().numpy(), 0, 1)
            
            # Compute perturbation from this instance's original
            seed_tensor = seed_tensor.to(input_tensor.device)
            diff = seed_tensor - input_tensor.reshape(3, 32, 32)
            l_inf = diff.abs().max().item()
            
            # Get prediction
            with torch.no_grad():
                seed_output = wrapped_model(seed_tensor.unsqueeze(0))
                if isinstance(seed_output, dict):
                    seed_output = seed_output['output']
                seed_pred = seed_output.argmax(dim=1).item()
                seed_probs = torch.softmax(seed_output[0], dim=0)
                seed_conf = seed_probs[seed_pred].item()
            
            axes[inst_idx, col].imshow(img_np, interpolation='nearest')
            title_color = 'red' if seed_pred != true_label else 'black'
            axes[inst_idx, col].set_title(f'Mutation {seed_idx+1}\nL∞={l_inf:.3f}\n'
                                          f'{CIFAR100_CLASSES[seed_pred]}\n({seed_conf:.2f})',
                                          fontsize=10, color=title_color, fontweight='bold' if seed_pred != true_label else 'normal')
            axes[inst_idx, col].axis('off')
        
        # Fill empty columns if less than 3 attempts
        for empty_col in range(3 + len(instance_seeds), 6):
            axes[inst_idx, empty_col].axis('off')
    
    # Add horizontal dash lines between rows
    for inst_idx in range(num_instances - 1):
        line_y = (inst_idx + 1) / num_instances
        fig.add_artist(plt.Line2D([0.05, 0.95], [line_y, line_y],
                                   transform=fig.transFigure, 
                                   color='black', linewidth=2, linestyle='--'))
    
    # Add epsilon annotation to title
    epsilon_list = [f"{info['epsilon']:.6f}" for info in instance_info]
    epsilon_str = f"ε = [{', '.join(epsilon_list)}]"
    
    # Count total mutations across all instances
    total_mutations = sum(len([s for s in all_fuzzers[i].seed_corpus.seeds 
    if (s.tensor.squeeze().reshape(3,32,32).to(instance_info[i]['input_tensor'].device) 
        - instance_info[i]['input_tensor'].squeeze().reshape(3,32,32)).abs().max().item() > 1e-6]) 
    for i in range(num_instances))
    
    plt.suptitle(f'Multi-Instance Fuzzing Analysis: No Adversarial Examples Found\n{epsilon_str} | {total_mutations} total mutations', 
                 fontsize=14, fontweight='bold')
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()
    
    print(f"\n💡 Observations:")
    print(f"  - Tested {len(instance_info)} instances with {total_mutations} total perturbation attempts")
    print(f"  - All attempts maintained correct classification for their respective instances")
    print(f"  - Model appears robust for these instances")
    print(f"\n💡 Suggestions to find counterexamples:")
    print(f"  1. Increase timeout (currently {config.timeout_seconds}s)")
    print(f"  2. Try more instances (currently using {len(instance_info)} random instances)")
    print(f"  3. Increase gradient mutation weight (currently {config.mutation_weights.get('gradient', 0)})")
    print(f"  4. Use GPU for faster iterations (currently: {config.device})")
# Out:
# ================================================================================
# FUZZING SUMMARY
# ================================================================================
#   Iterations: 2210 (18.4 it/s)
#   Time: 120.12s
#   Seeds explored: 1053
#   Neuron coverage: 55.11%
#   Counterexamples: 1049
# ================================================================================
#
# ================================================================================
# ORIGINAL INPUTS ANALYSIS
# ================================================================================
# Instance 1: True=tank, Pred=tank (0.415) ✓ Correct
# Instance 2: True=shrew, Pred=shrew (0.443) ✓ Correct
# ================================================================================
#
# ================================================================================
# SPECIFICATION SUMMARY
# ================================================================================
#
# Instance 1 - tank:
#   InputSpec:
#     Kind: BOX
#     Shape: torch.Size([1, 3, 32, 32])
#     Epsilon (L∞): 0.030590
#     Range: [-1.8824, 1.9966]
#   VNNLib Property:
#     Robustness check: Y_i >= Y_85 for all i ≠ 85
#     Meaning: Model should predict 'tank' for all inputs within ε=0.030590
#
# Instance 2 - shrew:
#   InputSpec:
#     Kind: BOX
#     Shape: torch.Size([1, 3, 32, 32])
#     Epsilon (L∞): 0.030590
#     Range: [-1.7904, 1.8804]
#   VNNLib Property:
#     Robustness check: Y_i >= Y_74 for all i ≠ 74
#     Meaning: Model should predict 'shrew' for all inputs within ε=0.030590
#
# ================================================================================
#
# ================================================================================
# 🎯 FOUND 1049 COUNTEREXAMPLE(S)!
# ================================================================================
#
# COUNTEREXAMPLE DETAILS:
#
# 1. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.309
# 2. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.352
# 3. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.308
# 4. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.309
# 5. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.353
# 6. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.351
# 7. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.308
# 8. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.308
# 9. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.308
# 10. TOP1_ROBUST: True=tank, Predicted=tractor, Conf=0.351
#
# ================================================================================
# COUNTEREXAMPLE VISUALIZATION
# ================================================================================
# ✅ Successfully found adversarial examples!

# %% [markdown]
# ## Fuzzing Trace Analysis
#
# Analyze execution traces to understand fuzzing behavior: mutation strategies, coverage evolution, and effectiveness.

# %%
# ============================================================================
# Trace Analysis: Load and visualize fuzzing execution traces
# ============================================================================

# Check if any trace files were generated
if len(trace_files) > 0:
    print(f"📊 Found {len(trace_files)} trace file(s). Starting analysis...\n")
    
    # Import trace analyzer
    from act.pipeline.fuzzing.trace_reader import TraceAnalyzer
    
    # Analyze each instance's traces
    for idx, trace_file in enumerate(trace_files):
        if not Path(trace_file).exists():
            print(f"⚠️  Warning: Trace file not found: {trace_file}")
            continue
        
        print(f"\n{'='*80}")
        print(f"INSTANCE {idx+1} - {instance_info[idx]['combo_id']}")
        print(f"{'='*80}")
        
        # Load trace analyzer
        analyzer = TraceAnalyzer(trace_file)
        
        # Show text overview
        analyzer.show_overview()
        
        print("\n")
        
        # Create visualizations
        try:
            analyzer.plot_overview()
        except Exception as e:
            print(f"⚠️  Could not generate plots: {e}")
        
        # DataFrame summary
        print(f"\n📊 Top 5 Coverage Gains:")
        df = analyzer.to_dataframe()
        if len(df) > 0:
            top_traces = df.nlargest(min(5, len(df)), 'coverage_delta')[
                ['trace_idx', 'iteration', 'strategy', 'coverage', 'coverage_delta']
            ]
            display(top_traces)
        else:
            print("   No traces captured (fuzzing may have finished too quickly)")
        
        # Strategy effectiveness
        if len(df) > 0:
            print(f"\n🔄 Strategy Comparison:")
            strategy_stats = df.groupby('strategy').agg({
                'coverage_delta': ['mean', 'std', 'max'],
                'trace_idx': 'count'
            }).round(4)
            strategy_stats.columns = ['Avg Gain', 'Std Dev', 'Max Gain', 'Count']
            display(strategy_stats.sort_values('Avg Gain', ascending=False))
        
        # Check for violations
        if 'violation' in df.columns:
            violations = df[df['violation'] == True]
            if len(violations) > 0:
                print(f"\n⚠️  Violation Analysis:")
                print(f"Found {len(violations)} violations:")
                display(violations[['trace_idx', 'iteration', 'strategy', 'coverage']])
            else:
                print(f"\n✅ No violations found in traces")
    
    # Aggregate analysis across all instances
    print(f"\n\n{'='*80}")
    print(f"AGGREGATE TRACE ANALYSIS - ALL INSTANCES")
    print(f"{'='*80}\n")
    
    all_dfs = []
    for trace_file in trace_files:
        if Path(trace_file).exists():
            try:
                analyzer = TraceAnalyzer(trace_file)
                df = analyzer.to_dataframe()
                all_dfs.append(df)
            except Exception as e:
                print(f"⚠️  Could not load trace: {e}")
    
    if len(all_dfs) > 0:
        # Concatenate all dataframes
        import pandas as pd
        combined_df = pd.concat(all_dfs, ignore_index=True)
        
        print(f"📊 Combined Statistics:")
        print(f"   Total traces: {len(combined_df)}")
        print(f"   Total iterations: {combined_df['iteration'].max()}")
        print(f"   Average coverage gain: {combined_df['coverage_delta'].mean():.4f}")
        print(f"   Max coverage gain: {combined_df['coverage_delta'].max():.4f}")
        
        print(f"\n🔄 Overall Strategy Performance:")
        overall_strategy_stats = combined_df.groupby('strategy').agg({
            'coverage_delta': ['mean', 'std', 'max'],
            'trace_idx': 'count'
        }).round(4)
        overall_strategy_stats.columns = ['Avg Gain', 'Std Dev', 'Max Gain', 'Count']
        display(overall_strategy_stats.sort_values('Avg Gain', ascending=False))
        
        # Plot combined strategy distribution
        print(f"\n📊 Combined Strategy Distribution:")
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
        
        # Pie chart
        strategy_counts = combined_df['strategy'].value_counts()
        ax1.pie(strategy_counts.values, labels=strategy_counts.index, autopct='%1.1f%%', startangle=90)
        ax1.set_title('Strategy Usage Distribution', fontsize=12, fontweight='bold')
        
        # Box plot
        combined_df.boxplot(column='coverage_delta', by='strategy', ax=ax2)
        ax2.set_title('Coverage Gain by Strategy', fontsize=12, fontweight='bold')
        ax2.set_xlabel('Strategy')
        ax2.set_ylabel('Coverage Delta')
        plt.suptitle('')  # Remove default title
        
        plt.tight_layout()
        plt.show()
        
        print(f"\n✨ Trace analysis complete!")
    else:
        print("⚠️  No valid trace data found for aggregate analysis")
    
else:
    print("⚠️  No trace files found. Tracing may not be enabled or fuzzing completed too quickly.")
    print("💡 To enable tracing, ensure trace_level > 0 in FuzzingConfig")
# Out:
# 📊 Found 2 trace file(s). Starting analysis...
#
#
# ================================================================================
# INSTANCE 1 - m:CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_116_sidx_8002_eps_0.0039|x:cifar100_2024|s:0|is:BOX|os:TOP1_ROBUST_m0.0
# ================================================================================
# ✅ Loaded 116 traces from traces.json
#
# 📊 Summary Statistics
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Total Traces:        116
#   Iterations:          0 → 1150
#   Violations Found:    0
#   Coverage Range:      55.2% → 55.2%
#   Final Coverage:      55.2%
#
# 🔄 Mutation Strategies
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   pgd             :  47 (40.5%)
#   activation      :  36 (31.0%)
#   boundary        :  24 (20.7%)
#   random          :   9 (7.8%)
# 📊 Top 5 Coverage Gains:
#    trace_idx  iteration    strategy  coverage  coverage_delta
# 0          0          0         pgd  0.552183        0.552183
# 1          1         10  activation  0.552183        0.000000
# 2          2         20    boundary  0.552183        0.000000
# 3          3         30  activation  0.552183        0.000000
# 4          4         40  activation  0.552183        0.000000
# 🔄 Strategy Comparison:
#             Avg Gain  Std Dev  Max Gain  Count
# strategy
# pgd           0.0117   0.0805    0.5522     47
# activation    0.0000   0.0000    0.0000     36
# boundary      0.0000   0.0000    0.0000     24
# random        0.0000   0.0000    0.0000      9
# ✅ No violations found in traces
#
# ================================================================================
# INSTANCE 2 - m:CIFAR100_resnet_medium_CIFAR100_resnet_medium_prop_idx_4071_sidx_6244_eps_0.0039|x:cifar100_2024|s:0|is:BOX|os:TOP1_ROBUST_m0.0
# ================================================================================
# ✅ Loaded 116 traces from traces.json
#
# 📊 Summary Statistics
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Total Traces:        116
#   Iterations:          0 → 1150
#   Violations Found:    0
#   Coverage Range:      55.2% → 55.2%
#   Final Coverage:      55.2%
#
# 🔄 Mutation Strategies
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   pgd             :  47 (40.5%)
#   activation      :  36 (31.0%)
#   boundary        :  24 (20.7%)
#   random          :   9 (7.8%)
# 📊 Top 5 Coverage Gains:
#    trace_idx  iteration    strategy  coverage  coverage_delta
# 0          0          0         pgd  0.552183        0.552183
# 1          1         10  activation  0.552183        0.000000
# 2          2         20    boundary  0.552183        0.000000
# 3          3         30  activation  0.552183        0.000000
# 4          4         40  activation  0.552183        0.000000
# 🔄 Strategy Comparison:
#             Avg Gain  Std Dev  Max Gain  Count
# strategy
# pgd           0.0117   0.0805    0.5522     47
# activation    0.0000   0.0000    0.0000     36
# boundary      0.0000   0.0000    0.0000     24
# random        0.0000   0.0000    0.0000      9
# ✅ No violations found in traces
#
#
# ================================================================================
# AGGREGATE TRACE ANALYSIS - ALL INSTANCES
# ================================================================================
#
# 📊 Combined Statistics:
#    Total traces: 232
#    Total iterations: 1150
#    Average coverage gain: 0.0048
#    Max coverage gain: 0.5522
#
# 🔄 Overall Strategy Performance:
#             Avg Gain  Std Dev  Max Gain  Count
# strategy
# pgd           0.0117   0.0801    0.5522     94
# activation    0.0000   0.0000    0.0000     72
# boundary      0.0000   0.0000    0.0000     48
# random        0.0000   0.0000    0.0000     18
# 📊 Combined Strategy Distribution:
# ✨ Trace analysis complete!

# %%
# ============================================================================
# Interactive Trace Explorer: Widget-based trace browser
# ============================================================================

if len(trace_files) > 0:
    print(f"🔍 Launching interactive explorer for {len(trace_files)} trace file(s)...\n")
    
    from act.pipeline.fuzzing.trace_reader import TraceAnalyzer
    from ipywidgets import Dropdown, VBox, HTML
    from IPython.display import display
    
    # Create dropdown to select which instance to explore
    instance_options = [(f"Instance {i+1} - {instance_info[i]['combo_id']}", i) 
                        for i in range(len(trace_files))]
    
    instance_dropdown = Dropdown(
        options=instance_options,
        description='Select Instance:',
        style={'description_width': 'initial'}
    )
    
    # Header
    header = HTML(value="<h3 style='color: #2e7d32;'>📊 Trace Explorer</h3>")
    
    print("Select an instance from the dropdown, then use the trace explorer widget below.")
    print("You can browse all traces and export individual ones.\n")
    
    # Function to launch explorer for selected instance
    def on_instance_change(change):
        inst_idx = change['new']
        trace_file = trace_files[inst_idx]
        
        print(f"\n{'='*80}")
        print(f"Loading Interactive Explorer for Instance {inst_idx+1}")
        print(f"⏳ Loading trace file and generating widgets (this may take a moment)...")
        print(f"{'='*80}\n")
        
        if Path(trace_file).exists():
            analyzer = TraceAnalyzer(trace_file)
            analyzer.interactive_explorer()
            print(f"\n✅ Explorer loaded! Use the dropdown above to browse traces.")
        else:
            print(f"❌ Trace file not found: {trace_file}")
    
    # Display instance selector
    display(VBox([header, instance_dropdown]))
    
    # Attach handler
    instance_dropdown.observe(on_instance_change, names='value')
    
    # Don't auto-trigger - let user select first (avoids slow initial load)
    print("💡 Select an instance from the dropdown above to launch the explorer.")
    
else:
    print("⚠️  No trace files available for interactive exploration.")
    print("💡 Make sure tracing is enabled in FuzzingConfig (trace_level > 0)")
# Out:
# 🔍 Launching interactive explorer for 2 trace file(s)...
#
# Select an instance from the dropdown, then use the trace explorer widget below.
# You can browse all traces and export individual ones.
# VBox(children=(HTML(value="<h3 style='color: #2e7d32;'>📊 Trace Explorer</h3>"), Dropdown(description='Select I…
# 💡 Select an instance from the dropdown above to launch the explorer.

# %% [markdown]
# ## Interactive Trace Explorer
#
# Use the dropdown widget below to interactively browse individual traces. Select any trace to see:
# - Detailed trace information (iteration, strategy, coverage)
# - Input tensor visualizations (before/after/diff heatmaps)
# - One-click export functionality
#
# **Note:** Requires `ipywidgets` package (`pip install ipywidgets`)
